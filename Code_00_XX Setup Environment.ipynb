# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow
# !pip install torch
# !pip install keras
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-macosx_10_14_x86_64.whl (244.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 MB 9.9 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 46.3 MB/s eta 0:00:0000:0100:01
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.11.23-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp39-cp39-macosx_10_10_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 38.4 MB/s eta 0:00:0000:0100:01
# Collecting numpy>=1.20
#   Downloading numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 46.0 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from tensorflow) (21.3)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.6 MB/s eta 0:00:0000:01
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.0 MB/s eta 0:00:0000:01
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl (980 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.5/980.5 kB 23.9 MB/s eta 0:00:0000:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.2 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 40.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from tensorflow) (65.5.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.4 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 47.9 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 25.3 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 12.1 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 41.7 MB/s eta 0:00:0000:0100:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.5 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.0/177.0 kB 9.6 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.3 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-5.1.0-py3-none-any.whl (21 kB)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.9 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, zipp, wrapt, werkzeug, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, charset-normalizer, cachetools, astunparse, absl-py, requests, opt-einsum, importlib-metadata, h5py, google-auth, requests-oauthlib, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 charset-normalizer-2.1.1 flatbuffers-22.11.23 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.7.0 importlib-metadata-5.1.0 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1 urllib3-1.26.13 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.11.0
# Collecting torch
#   Downloading torch-1.13.0-cp39-none-macosx_10_9_x86_64.whl (137.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from torch) (4.4.0)
# Installing collected packages: torch
# Successfully installed torch-1.13.0
# Requirement already satisfied: keras in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (2.11.0)
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 35.5 MB/s eta 0:00:0000:0100:01
# Collecting tqdm>=4.27
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from transformers) (2.28.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 10.0 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp39-cp39-macosx_10_9_x86_64.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.9/293.9 kB 12.4 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 kB 9.9 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.8.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-macosx_10_11_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 38.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests->transformers) (2022.9.24)
# Installing collected packages: tokenizers, tqdm, regex, pyyaml, filelock, huggingface-hub, transformers
# Successfully installed filelock-3.8.2 huggingface-hub-0.11.1 pyyaml-6.0 regex-2022.10.31 tokenizers-0.13.2 tqdm-4.64.1 transformers-4.25.1
# Collecting datasets
#   Downloading datasets-2.7.1-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 10.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (1.23.5)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (0.11.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting pyarrow>=6.0.0
#   Downloading pyarrow-10.0.1-cp39-cp39-macosx_10_14_x86_64.whl (25.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 37.3 MB/s eta 0:00:0000:0100:01
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp39-cp39-macosx_10_9_x86_64.whl (34 kB)
# Collecting dill<0.3.7
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (4.64.1)
# Collecting pandas
#   Downloading pandas-1.5.2-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 43.7 MB/s eta 0:00:0000:0100:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp39-cp39-macosx_10_9_x86_64.whl (360 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 16.5 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets) (2.1.1)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.3-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-macosx_10_9_x86_64.whl (36 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pytz, xxhash, pyarrow, multidict, fsspec, frozenlist, dill, async-timeout, yarl, responses, pandas, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.7.1 dill-0.3.6 frozenlist-1.3.3 fsspec-2022.11.0 multidict-6.0.3 multiprocess-0.70.14 pandas-1.5.2 pyarrow-10.0.1 pytz-2022.6 responses-0.18.0 xxhash-3.1.0 yarl-1.8.2
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting evaluate
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (1.5.2)
# Requirement already satisfied: dill in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (4.64.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2.28.1)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.11.1)
# Requirement already satisfied: responses<0.19 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (21.3)
# Requirement already satisfied: datasets>=2.0.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2.7.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (10.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2022.9.24)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->evaluate) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.3.0
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk) (4.64.1)
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk) (2022.10.31)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.3 joblib-1.2.0 nltk-3.7
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.3.0)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (3.7)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-1/lib/python3.9/site-packages (from nltk->rouge_score) (1.2.0)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24936 sha256=9bac8b69a2728f68ba497190deeda8c210b92ea21df29eb3b31d6d2e1e5253ed
#   Stored in directory: /Users/linkedin/Library/Caches/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
